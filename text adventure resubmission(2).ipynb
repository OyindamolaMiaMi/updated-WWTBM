# %% [markdown]
# <hr style="height:.9px;border:none;color:#333;background-color:#333;" />
# <hr style="height:.9px;border:none;color:#333;background-color:#333;" />
# <br><br>
#
# **WHO WANTS TO BE A MILLIONIARE (Replica)**
#
# Data Science: Python for Data Analysts <br>
#  <br>
# <br>
# Text Adventure Game <br>
# Author - Oyindamola Iwalehin (MiaMi) <br>
# <hr style="height:.9px;border:none;color:#333;background-color:#333;" />
# <hr style="height:.9px;border:none;color:#333;background-color:#333;" />
# <br>
#
#
# Who Wants to Be a Millionaire is a popular game show that originated in the United Kingdom in 1998 and has been adapted in over 160 countries worldwide. The objective of the game is for contestants to correctly answer a series of increasingly difficult multiple-choice questions in order to win a cash prize, with the ultimate goal of becoming a "millionaire" by correctly answering the final question.
#
# The show is typically hosted by a celebrity and features a contestant, who is given the opportunity to use "lifelines" such as "50/50" (eliminating two incorrect answers), "Phone a Friend" (calling a pre-approved friend for help), and "Ask the Audience" (polling the live studio audience) in order to assist them in answering the questions.
#
# The format of the show is designed to be high-stakes and dramatic, with a ticking clock and increasing levels of difficulty as the contestant progresses through the questions. The show has been very successful and has been credited with popularizing the concept of the "fastest finger" question, in which contestants must answer a question correctly and quickly in order to advance to the next round.
#
# As reported by the New York Times, the show's creator and executive producer, David Briggs, had the idea of "Who wants to be a millionaire" while he was working on a documentary about the United Kingdom's National Lottery. He thought of using the format of a trivia game show with a top prize of a million pounds to create a similar sensation of excitement and anticipation.
#
# Source:
# Briggs, D. (1999, September 22). The birth of a quiz show. The New York Times. Retrieved from https://www.nytimes.com/1999/09/22/arts/television-the-birth-of-a-quiz-show.html
#
# **USER'S INSTRUCTION**
#    1. Start by reading the rules and regulations of the game.
#    2.Familiarize yourself with the multiple-choice format of the questions.
#    3.Brush up on a wide range of general knowledge topics, including history, science, sports, and current events.
#    4.Develop strategies to eliminate incorrect answers, such as identifying outliers or making educated guesses.
#    5.Stay calm and focused while playing the game.
#    6.It is a replica of WWTBM, it is NOT the exact experience but its advised to have fun while aiming for wins. user is        only entitled to one lifeline in stage 2. use it!
#    7.Make decisions quickly, but don't rush.
#    8.Be confident in your choices, but also be willing to change your answer if you're unsure.
#    9.If you reach a high-pressure moment, take a deep breath and trust your instincts.
#    10.Install the imported packages before playing (if you don't have them)
#    11.Most importantly, have fun!

# %%
# a package from time called sleep basically for display in this case
from time import sleep
# to give random numbers when necessary
from random import randint
# importing emojis to make it creative and fun
from emoji import emojize
# importing flag package for country flags
import flag



# Game introduction and definition of the begining of the game as start game
def start_game():
      #importing sleep from time to beautify the logo and display process
    sleep(1.5)
    print(" *************************************************")
    print(" *            // who wants to be a \\\            *")
    print(" *            ||    MILLIONAIRE    ||            *")
    print(" *            \\\ who wants to be a //            *")
    print(" *************************************************\n")
    print("Welcome to Who Wants to Be a Millionaire!")
    # A welcome message to players
    print("Are you ready to test your knowledge and potentially become a millionaire? We're excited to have you join us on this journey.Let's see how far you can go! Remember, you can use a lifeline in stage 2. Good luck and have fun!")
    print("LET'S GET RIGHT INTO IT!")
    sleep(1.5)
    print("You look absolutely stunning tonight! look I know its 1 million dollars but i'll say take a deep breathe")
    print(" ")
    sleep(1.5)
    # defining the variable name and asking the user for name input
    name = input("Tell the audience! What is your name? (Input your name) : ").capitalize()
    print(f"{name.capitalize()} Welcome to the show!")
    print(" ")
    sleep(1.5)
    print(f"Everyone, a BIG ROUND OF APPLAUSE FOR OUR FIRST CANDIDATE TONIGHT {name.capitalize()}!")
    print(" ")
    sleep(2)
    print("👏" * 7)
    print(" ")
    #printing instructions and formatting name input
    print(f" {name.capitalize()}! You will have to go through 3 stages to win the game by which only statge 2 has the option of a lifeline.")
    print("You will be asked a series of questions, and you will have to choose the correct answer to win $$$.")
    print("Let's begin!\n")
    stage_1()
    
#defining stage 1

def stage_1():
    print("Welcome to Stage 1")
    print("stand a chance to win $100")
    # inputing questions and option for users choice ie [f"What is the capital of France?"]
    print(f"what is the capital of france?")
    options = [f"A. Paris {flag.flag('FR')}\nB. Rome {flag.flag('IT')}\nC. Madrid {flag.flag('ES')}\nD. London {flag.flag('GB')}"]
    for opt in options:
        print(opt)
        # defining the variable answer, based on correct input
    answer = input("Enter your choice:")
    
    if answer.upper() == "A" or answer.upper() == "PARIS"  or answer.lower() == "paris" or answer == {flag.flag('FR')} or answer== "🇫🇷":
        print("Correct!")
        print("You have advanced to the next stage and won $100!")
        print("\n")
        stage_2()
        
        # else comes to play when user fails this round
    else:
        print("Incorrect. Better luck next time.")
        exit()
# print an empty space
    print("\n")
    
    #defining stage 2 of the game
def stage_2():
    try:
        print("Welcome to Stage 2")
        print("stand a chance to win $1000")
#question = [f"What is the tallest mammal?"]
        print(f"What is the tallest mammal?")
        options = ["A. Giraffe", "B. Elephant", "C. Hippopotamus", "D. Rhinoceros"]
        for opt in options:
            print(opt)
        # ask user to choose 50:50 lifeline
        isAsk = askForFifty_fifty()
 # This takes 2 incorrect answers out of the options leaving user with 1 correct answer and 1 incorrect answer
        if isAsk:
            newOpts = options[:2]
            for opt in newOpts:
                print(opt)
            answer = input("Enter your choice: ")
            if answer.upper() == "A" or answer.upper() == "GIRAFFE"  or answer.lower() == "giraffe":
                print("Correct!")
                print("You have advanced to the next stage and won $1000!")
        
                print("\n")
                stage_3()
        else:
                        # the option for 5o:50
                       
                for opt in options:
                    print(opt)
                answer = input("Enter your choice: ")
                if answer.upper() == "A" or answer.upper() == "GIRAFFE"  or answer.lower() == "giraffe":
                    print("Correct!")
                    print("You have advanced to the next stage and won $1000!")
                    stage_3()
    except:
        print('Incorrect input! please enter yes or no')

                

        # basically telling python i need space between these stages when displaying
    print("\n")  
         
        #defining the stage 3 of the show
def stage_3():
    print("Welcome to Stage 3!")
    print("\n")
    print("stand a chance to win $1000000")
# question for stage 3 with its options
    print(f"What is the largest planet in our solar system?")
    options = ["A. Jupiter", "B. Saturn", "C. Uranus", "D. Neptune"]
    for opt in options:
        print(opt)
    answer = input("Enter your choice:")
    if answer.upper() == "A"  or answer.upper() == "JUPITER"  or answer.lower() == "jupiter":
        print("Correct!")
        print("You have won $1000000! You are officially a millionaire!")
        print("\n")
        win()
    else:
        print("Incorrect. Better luck next time.")
        exit()
    print("\n") 
    
    
    # defining the famous 50:50 as a lifeline
def askForFifty_fifty():
    print("Use 50/50 to take 2 answers out. leaving 2 answers, One of them is correct and the other one is not")
    choice = input("Do you want 50/50. Enter Yes or No: ")

    if (choice.lower() == "yes"):  #or answer.upper() == "YES"  or answer.lower() == "y" or answer.upper() == "Y"):
        return True
    #else:
    return False
#
def restart():
    play == True
    while play:
        start_game()
    # defining the win stage omg! 1million dollars is a lot of money to give out :)
def win():
    print("Congratulations! You have won the game and the prize money of $1,000,000")
    print("""
    
 

 __       __        __                                                                 
/  |  _  /  |      /  |                                                                
$$ | / \ $$ |      $$/        _______         _______          ______          ______  
$$ |/$  \$$ |      /  |      /       \       /       \        /      \        /      \ 
$$ /$$$  $$ |      $$ |      $$$$$$$  |      $$$$$$$  |      /$$$$$$  |      /$$$$$$  |
$$ $$/$$ $$ |      $$ |      $$ |  $$ |      $$ |  $$ |      $$    $$ |      $$ |  $$/ 
$$$$/  $$$$ |      $$ |      $$ |  $$ |      $$ |  $$ |      $$$$$$$$/       $$ |      
$$$/    $$$ |      $$ |      $$ |  $$ |      $$ |  $$ |      $$       |      $$ |      
$$/      $$/       $$/       $$/   $$/       $$/   $$/        $$$$$$$/       $$/       
                                                                                       
                                                                                       
                                                                                           
                                                      
                                                      
  


   __                              __        __        __        __                                 
 _/  |                            /  |      /  |      /  |      /  |                                
/ $$ |         _____  ____        $$/       $$ |      $$ |      $$/         ______         _______  
$$$$ |        /     \/    \       /  |      $$ |      $$ |      /  |       /      \       /       \ 
  $$ |        $$$$$$ $$$$  |      $$ |      $$ |      $$ |      $$ |      /$$$$$$  |      $$$$$$$  |
  $$ |        $$ | $$ | $$ |      $$ |      $$ |      $$ |      $$ |      $$ |  $$ |      $$ |  $$ |
 _$$ |_       $$ | $$ | $$ |      $$ |      $$ |      $$ |      $$ |      $$ \__$$ |      $$ |  $$ |
/ $$   |      $$ | $$ | $$ |      $$ |      $$ |      $$ |      $$ |      $$    $$/       $$ |  $$ |
$$$$$$/       $$/  $$/  $$/       $$/       $$/       $$/       $$/        $$$$$$/        $$/   $$/ 
                                                                                                    
                                                                                                    
                                                                                                    



 _______                         __        __                                                 
/       \                       /  |      /  |                                                
$$$$$$$  |        ______        $$ |      $$ |        ______          ______          _______ 
$$ |  $$ |       /      \       $$ |      $$ |       /      \        /      \        /       |
$$ |  $$ |      /$$$$$$  |      $$ |      $$ |       $$$$$$  |      /$$$$$$  |      /$$$$$$$/ 
$$ |  $$ |      $$ |  $$ |      $$ |      $$ |       /    $$ |      $$ |  $$/       $$      \ 
$$ |__$$ |      $$ \__$$ |      $$ |      $$ |      /$$$$$$$ |      $$ |             $$$$$$  |
$$    $$/       $$    $$/       $$ |      $$ |      $$    $$ |      $$ |            /     $$/ 
$$$$$$$/         $$$$$$/        $$/       $$/        $$$$$$$/       $$/             $$$$$$$/  
                                                                                              
                                                                                              
                                                                                              

  
                                                               

""")
   
    #defining the fail stage   
def fail():
    print("Sorry, you have failed the game.")
    play_again = input("Do you want to play again? (yes/no) ")
    if play_again.lower() == "yes":
        start_game()
    else:
        print("Thanks for playing!")
        exit()
        
# while loop to enable user play again if they wish to
play_again = "yes"
while play_again == "yes":
    start_game()
    play_again = input("Do you want to play again? (yes/no) ")
    if play_again.lower() == "no":
        print("Welldone! better try next time")
        exit()
        # finally end the game if user choose not to replay the game
        break
        
#start_game()
# Out:
#  *************************************************
#  *            // who wants to be a \\            *
#  *            ||    MILLIONAIRE    ||            *
#  *            \\ who wants to be a //            *
#  *************************************************
#
# Welcome to Who Wants to Be a Millionaire!
# Are you ready to test your knowledge and potentially become a millionaire? We're excited to have you join us on this journey.Let's see how far you can go! Remember, you can use a lifeline in stage 2. Good luck and have fun!
# LET'S GET RIGHT INTO IT!
# You look absolutely stunning tonight! look I know its 1 million dollars but i'll say take a deep breathe
#
# Tell the audience! What is your name? (Input your name) : o
# O Welcome to the show!
#
# Everyone, a BIG ROUND OF APPLAUSE FOR OUR FIRST CANDIDATE TONIGHT O!
#
# 👏👏👏👏👏👏👏
#
#  O! You will have to go through 3 stages to win the game by which only statge 2 has the option of a lifeline.
# ...
